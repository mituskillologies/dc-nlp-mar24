# %%
from nltk import pos_tag

# %%
pos_tag(['bigger'])
# Out:
# [('bigger', 'JJR')]

# %%
text = 'Pune (/ˈpuːnə/ POO-nə, Marathi: [ˈpuɳe] ⓘ), previously spelled in English as Poona (the official name until 1978),[15][16] is a city in Maharashtra state in the Deccan plateau in Western India. It is the administrative headquarters of the Pune district, and of Pune division. According to the 2011 Census of India, Pune is the ninth-most populous city in India with a population of 3.1 million residents within the city limits, and 7.2 million residents in the metropolitan region, making it the eight-most populous metropolitan area in India.[17] The city of Pune is part of Pune Metropolitan Region.[18] Pune is one of the largest IT hubs in India.[19][20] It is also one of the most important automobile and manufacturing hubs of India. Pune is often referred to as "Oxford of the East" because of its highly regarded educational institutions.[21][22][23] It has been ranked "the most liveable city in India" several times.'

# %%
text
# Out:
# 'Pune (/ˈpuːnə/ POO-nə, Marathi: [ˈpuɳe] ⓘ), previously spelled in English as Poona (the official name until 1978),[15][16] is a city in Maharashtra state in the Deccan plateau in Western India. It is the administrative headquarters of the Pune district, and of Pune division. According to the 2011 Census of India, Pune is the ninth-most populous city in India with a population of 3.1 million residents within the city limits, and 7.2 million residents in the metropolitan region, making it the eight-most populous metropolitan area in India.[17] The city of Pune is part of Pune Metropolitan Region.[18] Pune is one of the largest IT hubs in India.[19][20] It is also one of the most important automobile and manufacturing hubs of India. Pune is often referred to as "Oxford of the East" because of its highly regarded educational institutions.[21][22][23] It has been ranked "the most liveable city in India" several times.'

# %%
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
tags = pos_tag(word_tokenize(text))

# %%
tags
# Out:
# [('Pune', 'NNP'),
#  ('(', '('),
#  ('/ˈpuːnə/', 'JJ'),
#  ('POO-nə', 'NNP'),
#  (',', ','),
#  ('Marathi', 'NNP'),
#  (':', ':'),
#  ('[', 'NN'),
#  ('ˈpuɳe', 'NNP'),
#  (']', 'NNP'),
#  ('ⓘ', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('previously', 'RB'),
#  ('spelled', 'VBN'),
#  ('in', 'IN'),
#  ('English', 'NNP'),
#  ('as', 'IN'),
#  ('Poona', 'NNP'),
#  ('(', '('),
#  ('the', 'DT'),
#  ('official', 'NN'),
#  ('name', 'NN'),
#  ('until', 'IN'),
#  ('1978', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('[', '$'),
#  ('15', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('16', 'CD'),
#  (']', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('city', 'NN'),
#  ('in', 'IN'),
#  ('Maharashtra', 'NNP'),
#  ('state', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Deccan', 'NNP'),
#  ('plateau', 'NN'),
#  ('in', 'IN'),
#  ('Western', 'JJ'),
#  ('India', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('administrative', 'JJ'),
#  ('headquarters', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Pune', 'NNP'),
#  ('district', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('of', 'IN'),
#  ('Pune', 'NNP'),
#  ('division', 'NN'),
#  ('.', '.'),
#  ('According', 'VBG'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('2011', 'CD'),
#  ('Census', 'NNP'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  (',', ','),
#  ('Pune', 'NNP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('ninth-most', 'JJ'),
#  ('populous', 'JJ'),
#  ('city', 'NN'),
#  ('in', 'IN'),
#  ('India', 'NNP'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('population', 'NN'),
#  ('of', 'IN'),
#  ('3.1', 'CD'),
#  ('million', 'CD'),
#  ('residents', 'NNS'),
#  ('within', 'IN'),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('limits', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('7.2', 'CD'),
#  ('million', 'CD'),
#  ('residents', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('metropolitan', 'JJ'),
#  ('region', 'NN'),
#  (',', ','),
#  ('making', 'VBG'),
#  ('it', 'PRP'),
#  ('the', 'DT'),
#  ('eight-most', 'JJ'),
#  ('populous', 'JJ'),
#  ('metropolitan', 'JJ'),
#  ('area', 'NN'),
#  ('in', 'IN'),
#  ('India', 'NNP'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('17', 'CD'),
#  (']', 'IN'),
#  ('The', 'DT'),
#  ('city', 'NN'),
#  ('of', 'IN'),
#  ('Pune', 'NNP'),
#  ('is', 'VBZ'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('Pune', 'NNP'),
#  ('Metropolitan', 'NNP'),
#  ('Region', 'NNP'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('18', 'CD'),
#  (']', 'NN'),
#  ('Pune', 'NNP'),
#  ('is', 'VBZ'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('largest', 'JJS'),
#  ('IT', 'NN'),
#  ('hubs', 'NN'),
#  ('in', 'IN'),
#  ('India', 'NNP'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('19', 'CD'),
#  (']', 'JJ'),
#  ('[', '$'),
#  ('20', 'CD'),
#  (']', 'NN'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('also', 'RB'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('important', 'JJ'),
#  ('automobile', 'NN'),
#  ('and', 'CC'),
#  ('manufacturing', 'NN'),
#  ('hubs', 'NN'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  ('.', '.'),
#  ('Pune', 'NNP'),
#  ('is', 'VBZ'),
#  ('often', 'RB'),
#  ('referred', 'VBN'),
#  ('to', 'TO'),
#  ('as', 'IN'),
#  ('``', '``'),
#  ('Oxford', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('East', 'NNP'),
#  ("''", "''"),
#  ('because', 'IN'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('highly', 'RB'),
#  ('regarded', 'JJ'),
#  ('educational', 'JJ'),
#  ('institutions', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('21', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('22', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('23', 'CD'),
#  (']', 'NN'),
#  ('It', 'PRP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('ranked', 'VBN'),
#  ('``', '``'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('liveable', 'JJ'),
#  ('city', 'NN'),
#  ('in', 'IN'),
#  ('India', 'NNP'),
#  ("''", "''"),
#  ('several', 'JJ'),
#  ('times', 'NNS'),
#  ('.', '.')]

# %%
for tag in tags:
    print('word:',tag[0], '\t\tTag:',tag[1])
# Out:
# word: Pune 		Tag: NNP
# word: ( 		Tag: (
# word: /ˈpuːnə/ 		Tag: JJ
# word: POO-nə 		Tag: NNP
# word: , 		Tag: ,
# word: Marathi 		Tag: NNP
# word: : 		Tag: :
# word: [ 		Tag: NN
# word: ˈpuɳe 		Tag: NNP
# word: ] 		Tag: NNP
# word: ⓘ 		Tag: NNP
# word: ) 		Tag: )
# word: , 		Tag: ,
# word: previously 		Tag: RB
# word: spelled 		Tag: VBN
# word: in 		Tag: IN
# word: English 		Tag: NNP
# word: as 		Tag: IN
# word: Poona 		Tag: NNP
# word: ( 		Tag: (
# word: the 		Tag: DT
# word: official 		Tag: NN
# word: name 		Tag: NN
# word: until 		Tag: IN
# word: 1978 		Tag: CD
# word: ) 		Tag: )
# word: , 		Tag: ,
# word: [ 		Tag: $
# word: 15 		Tag: CD
# word: ] 		Tag: NNP
# word: [ 		Tag: VBD
# word: 16 		Tag: CD
# word: ] 		Tag: NN
# word: is 		Tag: VBZ
# word: a 		Tag: DT
# word: city 		Tag: NN
# word: in 		Tag: IN
# word: Maharashtra 		Tag: NNP
# word: state 		Tag: NN
# word: in 		Tag: IN
# word: the 		Tag: DT
# word: Deccan 		Tag: NNP
# word: plateau 		Tag: NN
# word: in 		Tag: IN
# word: Western 		Tag: JJ
# word: India 		Tag: NNP
# word: . 		Tag: .
# word: It 		Tag: PRP
# word: is 		Tag: VBZ
# word: the 		Tag: DT
# word: administrative 		Tag: JJ
# word: headquarters 		Tag: NN
# word: of 		Tag: IN
# word: the 		Tag: DT
# word: Pune 		Tag: NNP
# word: district 		Tag: NN
# word: , 		Tag: ,
# word: and 		Tag: CC
# word: of 		Tag: IN
# word: Pune 		Tag: NNP
# word: division 		Tag: NN
# word: . 		Tag: .
# word: According 		Tag: VBG
# word: to 		Tag: TO
# word: the 		Tag: DT
# word: 2011 		Tag: CD
# word: Census 		Tag: NNP
# word: of 		Tag: IN
# word: India 		Tag: NNP
# word: , 		Tag: ,
# word: Pune 		Tag: NNP
# word: is 		Tag: VBZ
# word: the 		Tag: DT
# word: ninth-most 		Tag: JJ
# word: populous 		Tag: JJ
# word: city 		Tag: NN
# word: in 		Tag: IN
# word: India 		Tag: NNP
# word: with 		Tag: IN
# word: a 		Tag: DT
# word: population 		Tag: NN
# word: of 		Tag: IN
# word: 3.1 		Tag: CD
# word: million 		Tag: CD
# word: residents 		Tag: NNS
# word: within 		Tag: IN
# word: the 		Tag: DT
# word: city 		Tag: NN
# word: limits 		Tag: NNS
# word: , 		Tag: ,
# word: and 		Tag: CC
# word: 7.2 		Tag: CD
# word: million 		Tag: CD
# word: residents 		Tag: NNS
# word: in 		Tag: IN
# word: the 		Tag: DT
# word: metropolitan 		Tag: JJ
# word: region 		Tag: NN
# word: , 		Tag: ,
# word: making 		Tag: VBG
# word: it 		Tag: PRP
# word: the 		Tag: DT
# word: eight-most 		Tag: JJ
# word: populous 		Tag: JJ
# word: metropolitan 		Tag: JJ
# word: area 		Tag: NN
# word: in 		Tag: IN
# word: India 		Tag: NNP
# word: . 		Tag: .
# word: [ 		Tag: CC
# word: 17 		Tag: CD
# word: ] 		Tag: IN
# word: The 		Tag: DT
# word: city 		Tag: NN
# word: of 		Tag: IN
# word: Pune 		Tag: NNP
# word: is 		Tag: VBZ
# word: part 		Tag: NN
# word: of 		Tag: IN
# word: Pune 		Tag: NNP
# word: Metropolitan 		Tag: NNP
# word: Region 		Tag: NNP
# word: . 		Tag: .
# word: [ 		Tag: CC
# word: 18 		Tag: CD
# word: ] 		Tag: NN
# word: Pune 		Tag: NNP
# word: is 		Tag: VBZ
# word: one 		Tag: CD
# word: of 		Tag: IN
# word: the 		Tag: DT
# word: largest 		Tag: JJS
# word: IT 		Tag: NN
# word: hubs 		Tag: NN
# word: in 		Tag: IN
# word: India 		Tag: NNP
# word: . 		Tag: .
# word: [ 		Tag: CC
# word: 19 		Tag: CD
# word: ] 		Tag: JJ
# word: [ 		Tag: $
# word: 20 		Tag: CD
# word: ] 		Tag: NN
# word: It 		Tag: PRP
# word: is 		Tag: VBZ
# word: also 		Tag: RB
# word: one 		Tag: CD
# word: of 		Tag: IN
# word: the 		Tag: DT
# word: most 		Tag: RBS
# word: important 		Tag: JJ
# word: automobile 		Tag: NN
# word: and 		Tag: CC
# word: manufacturing 		Tag: NN
# word: hubs 		Tag: NN
# word: of 		Tag: IN
# word: India 		Tag: NNP
# word: . 		Tag: .
# word: Pune 		Tag: NNP
# word: is 		Tag: VBZ
# word: often 		Tag: RB
# word: referred 		Tag: VBN
# word: to 		Tag: TO
# word: as 		Tag: IN
# word: `` 		Tag: ``
# word: Oxford 		Tag: NNP
# word: of 		Tag: IN
# word: the 		Tag: DT
# word: East 		Tag: NNP
# word: '' 		Tag: ''
# word: because 		Tag: IN
# word: of 		Tag: IN
# word: its 		Tag: PRP$
# word: highly 		Tag: RB
# word: regarded 		Tag: JJ
# word: educational 		Tag: JJ
# word: institutions 		Tag: NNS
# word: . 		Tag: .
# word: [ 		Tag: $
# word: 21 		Tag: CD
# word: ] 		Tag: NNP
# word: [ 		Tag: VBD
# word: 22 		Tag: CD
# word: ] 		Tag: NNP
# word: [ 		Tag: VBD
# word: 23 		Tag: CD
# word: ] 		Tag: NN
# word: It 		Tag: PRP
# word: has 		Tag: VBZ
# word: been 		Tag: VBN
# word: ranked 		Tag: VBN
# word: `` 		Tag: ``
# word: the 		Tag: DT
# word: most 		Tag: RBS
# word: liveable 		Tag: JJ
# word: city 		Tag: NN
# word: in 		Tag: IN
# word: India 		Tag: NNP
# word: '' 		Tag: ''
# word: several 		Tag: JJ
# word: times 		Tag: NNS
# word: . 		Tag: .

# %%
# Print only the verb from this text

# %%
for tag in tags:
    if tag[1].startswith('V') and tag[0].isalpha():
        print(tag[0])
# Out:
# spelled
# is
# is
# According
# is
# making
# is
# is
# is
# is
# referred
# has
# been
# ranked

# %%
# Print only root form of the words

# %%
from nltk.stem import WordNetLemmatizer

# %%
wnl = WordNetLemmatizer()

# %%
for tag in tags:
    if tag[1].startswith('V') and tag[0].isalpha():
        print(wnl.lemmatize(tag[0], pos='v'))
# Out:
# spell
# be
# be
# According
# be
# make
# be
# be
# be
# be
# refer
# have
# be
# rank
